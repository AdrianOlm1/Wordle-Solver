# %%
## Letter Creator
letDict = {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0}

with open('words.txt', 'r') as words:
    for word in words:
        for c in word.strip():
            letDict[c] += 1

    rankedLetters = {char: rank for rank, (char, _) in enumerate(sorted(letDict.items(), key=lambda item: item[1], reverse = False))}
    print(rankedLetters)
# Out:
# {'q': 0, 'x': 1, 'j': 2, 'z': 3, 'v': 4, 'w': 5, 'f': 6, 'k': 7, 'b': 8, 'g': 9, 'h': 10, 'c': 11, 'y': 12, 'm': 13, 'p': 14, 'd': 15, 'u': 16, 'n': 17, 't': 18, 'l': 19, 'i': 20, 'r': 21, 'o': 22, 'a': 23, 's': 24, 'e': 25}

# %%
## Digram Creator
diDict = {}

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(4):
            di = word[i] + word[i+1]
            if di not in diDict:
                diDict.update({di : 0})
            else:
                diDict[di] += 1

    rankedDigram = {char: rank for rank, (char, _) in enumerate(sorted(diDict.items(), key=lambda item: item[1], reverse = False))}

    #print(rankedDigram)

# %%
#Triagram Creator
triDict = {}

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(3):
            tri = word[i] + word[i+1] + word[i+2]
            if tri not in triDict:
                triDict.update({tri : 0})
            else:
                triDict[tri] += 1

    rankedTrigram = {char: rank for rank, (char, _) in enumerate(sorted(triDict.items(), key=lambda item: item[1], reverse = False))}

    #print(rankedTrigram)

# %%
#quad Creator
quadDict = {}

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(2):
            quad = word[i] + word[i+1] + word[i+2] + word[i+3]
            if quad not in quadDict:
                quadDict.update({quad : 0})
            else:
                quadDict[quad] += 1

    #print(quadDict)

    rankedQuadgram = {char: rank for rank, (char, _) in enumerate(sorted(quadDict.items(), key=lambda item: item[1], reverse = False))}

    #print(rankedQuadgram)

# %%
wordDict = {}
with open('words.txt', 'r') as words:
    for word in words:
        index = 0
        for c in word.strip():
            index += rankedLetters[c]
        for i in range(4):
            di = word[i]+word[i+1]
            index += rankedDigram[di]
        for i in range(3):
            tri = word[i] + word[i+1] + word[i+2]
            index += rankedTrigram[tri]
        for i in range(2):
            quad = word[i] + word[i+1] + word[i+2] + word[i+3]
            index += rankedQuadgram[quad]

        wordDict.update({word.strip() : index})

    #print(wordDict)

    sortedWord = sorted(wordDict.items(), key=lambda item: item[1], reverse = True)

    rankedWordList = [word for rank, (word, _) in enumerate(sortedWord)]

    #print(rankedWordList)

# %%
def removeCorrectLetter(letter, index):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if entry[index] == letter]

def removeAlmostLetter(letter, index):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if letter in entry and entry[index] != letter]

def removeIncorrectLetter(letter):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if letter not in entry]

rankedWordMod = rankedWordList.copy()

for i in range(6):

    if len(rankedWordMod) == 1:
        print("-------------------------------")
        print(f"------Final Guess: {rankedWordMod[0]}------")
        print("-------------------------------")
        continue
        
    
    word = rankedWordMod[0]
    
    
    print("-------------------------------")
    print(f"---------Guess: {word}----------")
    print("-------------------------------")
    rankedWordMod.remove(word)

    for j in range(5):
        userInput = input(f"Was {word[j]} in the word? (y/n)")
        if userInput == 'y':
            userInput = input(f"Was {word[j]} in Correct Spot? (y/n)")
            if userInput == 'y':
                removeCorrectLetter(word[j], j)
            else:
                removeAlmostLetter(word[j], j)
        else:
            removeIncorrectLetter(word[j])
# Out:
#   Cell In[50], line 21
#     return 0
#     ^
# SyntaxError: 'return' outside function

# %%
#Letter creatror with an emphasis on placement
placeLetterDict = [
    {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0},
    {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0},
    {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0},
    {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0},
    {"a" : 0, "b" : 0, "c" : 0, "d" : 0, "e" : 0, "f" : 0, "g" : 0, "h" : 0, "i" : 0, "j" : 0, "k" : 0, "l" : 0, "m" : 0, "n" : 0, "o" : 0, "p" : 0, "q" : 0, "r" : 0, "s" : 0, "t" : 0, "u" : 0, "v" : 0, "w" : 0, "x" : 0, "y" : 0, "z" : 0}
]
with open('words.txt', 'r') as words:
    for word in words:
        for i in range(5):
            placeLetterDict[i][word[i]] += 1
            
    rankedPlaceLetter = []
    for letDict in placeLetterDict:
        rankedPlaceLetter.append({char: rank for rank, (char, _) in enumerate(sorted(letDict.items(), key=lambda item: item[1], reverse = False))})
    #print(rankedPlaceLetter)

# %%
## Digram Creator
placeDiDict = [{},{},{},{}]

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(4):
            di = word[i] + word[i+1]
            if di not in placeDiDict[i]:
                placeDiDict[i].update({di : 0})
            else:
                placeDiDict[i][di] += 1

    rankedPlaceDiagram = []
    for diDict in placeDiDict:
        rankedPlaceDiagram.append({char: rank for rank, (char, _) in enumerate(sorted(diDict.items(), key=lambda item: item[1], reverse = False))})
    #print(rankedPlaceDiagram)

# %%
## Digram Creator
placeTriDict = [{},{},{}]

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(3):
            tri = word[i] + word[i+1] + word[i+2]
            if tri not in placeTriDict[i]:
                placeTriDict[i].update({tri : 0})
            else:
                placeTriDict[i][tri] += 1

    rankedPlaceTrigram = []
    for triDict in placeTriDict:
        rankedPlaceTrigram.append({char: rank for rank, (char, _) in enumerate(sorted(triDict.items(), key=lambda item: item[1], reverse = False))})
    #print(rankedPlaceTrigram)

# %%
## Digram Creator
placeQuadDict = [{},{},{}]

with open('words.txt', 'r') as words:
    for word in words:
        for i in range(2):
            quad = word[i] + word[i+1] + word[i+2] + word[i+3]
            if quad not in placeQuadDict[i]:
                placeQuadDict[i].update({quad : 0})
            else:
                placeQuadDict[i][quad] += 1

    rankedPlaceQuadgram = []
    for quadDict in placeQuadDict:
        rankedPlaceQuadgram.append({char: rank for rank, (char, _) in enumerate(sorted(quadDict.items(), key=lambda item: item[1], reverse = False))})
    #print(rankedPlaceQuadgram)

# %%
wordDict = {}
with open('words.txt', 'r') as words:
    for word in words:
        index = 0
        for i in range(5):
            c = word[i]
            index += rankedPlaceLetter[i][c]
        for i in range(4):
            di = word[i]+word[i+1]
            index += rankedPlaceDiagram[i][di]
        for i in range(3):
            tri = word[i] + word[i+1] + word[i+2]
            index += rankedPlaceTrigram[i][tri]
        for i in range(2):
            quad = word[i] + word[i+1] + word[i+2] + word[i+3]
            index += rankedPlaceQuadgram[i][quad]

        wordDict.update({word.strip() : index})

    #print(wordDict)

    sortedWord = sorted(wordDict.items(), key=lambda item: item[1], reverse = True)

    rankedWordList = [word for rank, (word, _) in enumerate(sortedWord)]

    #print(rankedWordList)

# %%
## Manual Solver with improvements to solve on edge case of similar lettered words and not to reask letters already known
from collections import Counter

def removeCorrectLetter(letter, index):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if entry[index] == letter]

def removeAlmostLetter(letter, index):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if letter in entry and entry[index] != letter]

def removeIncorrectLetter(letter):
    global rankedWordMod
    rankedWordMod = [entry for entry in rankedWordMod if letter not in entry]

def lowerBoundRemove(letter, count):
    global rankedWordMod
    rankedWordMod = [word for word in rankedWordMod if word.count(letter) >= count]

def upperBoundRemove(letter, count):
    global rankedWordMod
    rankedWordMod = [word for word in rankedWordMod if word.count(letter) == count]

## to handle similar words and not get stuck
def greaterTwoCase(word):
    usedLetters = set(finalWord) - {'_'}  # skip confirmed letters

    # Build a pool of remaining letters not in the known correct positions
    remainingLetters = set()
    for word in rankedWordMod:
        for ch in word:
            if ch not in usedLetters:
                remainingLetters.add(ch)
    
    # First, try to find a word with 5 unique letters from remaining letters
    for word in rankedWordList:
        if len(set(word)) == 5 and set(word).issubset(remainingLetters):
            return word
                
    # attempt to look for word with set of 4 letters
    for word in rankedWordList:
        # Filter the word to only contain letters in remainingLetters
        filtered_letters = set(c for c in word if c in remainingLetters)
            
        # Check if there are at least 4 unique letters in the word that are in remainingLetters
        if len(filtered_letters) >= 4:
            return word

    # attempt to look for word with set of 3 letters
    for word in rankedWordList:
        # Filter the word to only contain letters in remainingLetters
        filtered_letters = set(c for c in word if c in remainingLetters)
            
        # Check if there are at least 3 unique letters in the word that are in remainingLetters
        if len(filtered_letters) >= 3:
            return word
    
    # If all else fails
    return "nope"

# ----------------------------------
# Main interactive function
# ----------------------------------
def solveWithUserInput():
    global rankedWordMod
    rankedWordMod = rankedWordList.copy()
    correctCount = 0
    tried = False
    finalWord = ['_'] * 5

    for i in range(6):
        twoBranch = False

        if len(rankedWordMod) == 1:
            print("-------------------------------")
            print(f"------Final Guess: {rankedWordMod[0]}------")
            print("-------------------------------")
            break

        if correctCount >= 3 and len(rankedWordMod) > 3 and not tried:
            bestWord = greaterTwoCase(finalWord)
            if bestWord != "nope":
                word = bestWord
                twoBranch = True
            else:
                word = rankedWordMod[0]
                tried = True
        else:
            word = rankedWordMod[0]
            rankedWordMod.remove(word)

        print("-------------------------------")
        print(f"---------Guess: {word}----------")
        print("-------------------------------")

        guessCounts = Counter(word)

        for j in range(5):
            if finalWord[j] != '_' and not twoBranch:
                continue

            guessedLetter = word[j]

            userInput = input(f"Was '{guessedLetter}' in the word? (position {j+1}) (y/n): ").strip().lower()
            if userInput == 'y':
                spotInput = input(f"Was '{guessedLetter}' in the correct spot (position {j+1})? (y/n): ").strip().lower()
                if spotInput == 'y':
                    if finalWord[j] != guessedLetter:
                        finalWord[j] = guessedLetter
                        correctCount += 1
                    removeCorrectLetter(guessedLetter, j)
                else:
                    removeAlmostLetter(guessedLetter, j)

                if guessCounts[guessedLetter] != 1:
                    countInput = input(f"Do all occurences '{guessedLetter}' appear in the word? (y/n)").strip()
                    if countInput == 'y':
                        lowerBoundRemove(guessedLetter, int(guessCounts[guessedLetter]))
                    else:
                        countInput = input(f"How many occurences '{guessedLetter}' appear in the word? (enter a number)").strip()
                        upperBoundRemove(guessedLetter, int(countInput))
            else:
                removeIncorrectLetter(guessedLetter)

    print("Game ended.")

solveWithUserInput()
# Out:
# -------------------------------
# ---------Guess: pares----------
# -------------------------------
# Was 'p' in the word? (position 1) (y/n):  n
# Was 'a' in the word? (position 2) (y/n):  y
# Was 'a' in the correct spot (position 2)? (y/n):  y
# Was 'r' in the word? (position 3) (y/n):  n
# Was 'e' in the word? (position 4) (y/n):  y
# Was 'e' in the correct spot (position 4)? (y/n):  y
# Was 's' in the word? (position 5) (y/n):  n
# -------------------------------
# ---------Guess: maned----------
# -------------------------------
# Was 'm' in the word? (position 1) (y/n):  n
# Was 'n' in the word? (position 3) (y/n):  n
# Was 'd' in the word? (position 5) (y/n):  n
# -------------------------------
# ---------Guess: cavel----------
# -------------------------------
# Was 'c' in the word? (position 1) (y/n):  n
# Was 'v' in the word? (position 3) (y/n):  n
# Was 'l' in the word? (position 5) (y/n):  y
# Was 'l' in the correct spot (position 5)? (y/n):  y
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 127
#     123                 removeIncorrectLetter(guessedLetter)
#     125     print("Game ended.")
# --> 127 solveWithUserInput()
#
# Cell In[6], line 81, in solveWithUserInput()
#      78     break
#      80 if correctCount >= 3 and len(rankedWordMod) > 3 and not tried:
# ---> 81     bestWord = greaterTwoCase(finalWord)
#      82     if bestWord != "nope":
#      83         word = bestWord
#
# Cell In[6], line 26, in greaterTwoCase(word)
#      25 def greaterTwoCase(word):
# ---> 26     usedLetters = set(finalWord) - {'_'}  # skip confirmed letters
#      28     # Build a pool of remaining letters not in the known correct positions
#      29     remainingLetters = set()
#
# NameError: name 'finalWord' is not defined

# %%
## automatic solver for one word
import random
from collections import Counter

def solve(hiddenWord):
    def removeCorrectLetter(letter, index):
        nonlocal rankedWordMod
        rankedWordMod = [entry for entry in rankedWordMod if entry[index] == letter]

    def removeAlmostLetter(letter, index):
        nonlocal rankedWordMod
        rankedWordMod = [entry for entry in rankedWordMod if letter in entry and entry[index] != letter]

    def removeIncorrectLetter(letter):
        nonlocal rankedWordMod
        rankedWordMod = [entry for entry in rankedWordMod if letter not in entry]

    def greaterTwoCase(word):
        usedLetters = set(finalWord) - {'_'}  # skip confirmed letters

        # Build a pool of remaining letters not in the known correct positions
        remainingLetters = set()
        for word in rankedWordMod:
            for ch in word:
                if ch not in usedLetters:
                    remainingLetters.add(ch)

        print(remainingLetters)
        # First, try to find a word with 5 unique letters from remaining letters
        for word in rankedWordList:
            if len(set(word)) == 5 and set(word).issubset(remainingLetters):
                return word

        for word in rankedWordList:
            # Filter the word to only contain letters in remainingLetters
            filtered_letters = set(c for c in word if c in remainingLetters)
            
            # Check if there are at least 4 unique letters in the word that are in remainingLetters
            if len(filtered_letters) >= 4:
                return word

        # attempt to look for word with set of 3 letters
        for word in rankedWordList:
            # Filter the word to only contain letters in remainingLetters
            filtered_letters = set(c for c in word if c in remainingLetters)
            
            # Check if there are at least 3 unique letters in the word that are in remainingLetters
            if len(filtered_letters) >= 3:
                return word
    
        # If all else fails
        return "nope"

    ## used when all letter guesses are in the word (indefinite)
    def lowerBoundRemove(letter, count):
        nonlocal rankedWordMod
        rankedWordMod = [
            word for word in rankedWordMod
            if word.count(letter) >= count
        ]

    ## used when we know x's amount of letter must be word (definite)
    def upperBoundRemove(letter, count):
        nonlocal rankedWordMod
        rankedWordMod = [
            word for word in rankedWordMod
            if word.count(letter) == count
        ]

    rankedWordMod = rankedWordList.copy()
    correctCount = 0
    tried = False
    finalWord = ['_'] * 5

    for i in range(6):
        if i == 5:
            tried = True
        twoBranch = False

        if len(rankedWordMod) == 1:
            print("-------------------------------")
            print(f"------Final Guess: {rankedWordMod[0]}------")
            print("-------------------------------")
            return i

        if correctCount >= 3 and len(rankedWordMod) > 3 and not tried:
            bestWord = greaterTwoCase(finalWord)
            print(rankedWordMod)
            if bestWord != "nope":
                print("Tried w/ possible combination")
                word = bestWord
                twoBranch = True
            else:
                tried = True
                print("Tried w/ possible no combination")
                word = rankedWordMod[0]
                rankedWordMod.remove(word)
        else:
            word = rankedWordMod[0]
            rankedWordMod.remove(word)

        print("-------------------------------")
        print(f"---------Guess: {word}----------")
        print("-------------------------------")

        guessCounts = Counter(word)
        actualCounts = Counter(hiddenWord)

        for j in range(5):
            ## gives our hidden and guess word
            hiddenLetter = hiddenWord[j]
            guessedLetter = word[j]
            
            if finalWord[j] != '_' and not twoBranch:
                continue
            print(f"Was {guessedLetter} in the word?")
            if guessedLetter in hiddenWord:
                print("Computer: Yes")
                print(f"Was {guessedLetter} in Correct Spot?")
                if guessedLetter == hiddenLetter:
                    print("Computer: Yes")
                    if finalWord[j] != guessedLetter:
                        correctCount += 1
                        finalWord[j] = guessedLetter
                    if correctCount == 5:
                        return i+1
                    removeCorrectLetter(guessedLetter, j)
                else:
                    print("Computer: No")
                    removeAlmostLetter(guessedLetter, j)

                ## to check if there are multiple all correct letters
                print(f"How many counts of {guessedLetter} are there?")
                if guessCounts[guessedLetter] <= actualCounts[guessedLetter]:
                    print(f"Computer: There is at least {guessCounts[guessedLetter]} (indefinetly)")
                    lowerBoundRemove(guessedLetter, guessCounts[guessedLetter])
                    
                ## to check if there are multiple correct letters with some incorrect
                elif guessCounts[guessedLetter] > actualCounts[guessedLetter]:
                    print(f"Computer: There are {actualCounts[guessedLetter]} (definetly)")
                    upperBoundRemove(guessedLetter, actualCounts[guessedLetter])
            else:
                print("Computer: No")
                removeIncorrectLetter(guessedLetter)
    return 7  # max attempts used


# Run the solver
#random_word = random.choice(rankedWordList)
random_word = "hazel"
print("Hidden Word is:", random_word)
guesses = solve(random_word)
print(f"This took {guesses} guesses")
# Out:
# Hidden Word is: hazel
# -------------------------------
# ---------Guess: pares----------
# -------------------------------
# Was p in the word?
# Computer: No
# Was a in the word?
# Computer: Yes
# Was a in Correct Spot?
# Computer: Yes
# How many counts of a are there?
# Computer: There is at least 1 (indefinetly)
# Was r in the word?
# Computer: No
# Was e in the word?
# Computer: Yes
# Was e in Correct Spot?
# Computer: Yes
# How many counts of e are there?
# Computer: There is at least 1 (indefinetly)
# Was s in the word?
# Computer: No
# -------------------------------
# ---------Guess: maned----------
# -------------------------------
# Was m in the word?
# Computer: No
# Was n in the word?
# Computer: No
# Was d in the word?
# Computer: No
# -------------------------------
# ---------Guess: cavel----------
# -------------------------------
# Was c in the word?
# Computer: No
# Was v in the word?
# Computer: No
# Was l in the word?
# Computer: Yes
# Was l in Correct Spot?
# Computer: Yes
# How many counts of l are there?
# Computer: There is at least 1 (indefinetly)
# {'z', 'h', 'g', 'b'}
# ['hazel', 'babel', 'label', 'bagel']
# Tried w/ possible combination
# -------------------------------
# ---------Guess: bight----------
# -------------------------------
# Was b in the word?
# Computer: No
# Was i in the word?
# Computer: No
# Was g in the word?
# Computer: No
# Was h in the word?
# Computer: Yes
# Was h in Correct Spot?
# Computer: No
# How many counts of h are there?
# Computer: There is at least 1 (indefinetly)
# Was t in the word?
# Computer: No
# -------------------------------
# ------Final Guess: hazel------
# -------------------------------
# This took 4 guesses
